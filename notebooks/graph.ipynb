# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from src.graph.graph import graph

app = graph.compile()
# Out:
# /Users/sergio.fernandez/Documents - KV7M912HQ6/AI-Initiative/AI-Accelerators/Enroute-ReimburstMate-Telgram-Bot/src/graph/graph.py:32: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'typing.Dict[str, typing.Any]'.
#   graph.add_node("agent_plan", AgentPlan())
# /Users/sergio.fernandez/Documents - KV7M912HQ6/AI-Initiative/AI-Accelerators/Enroute-ReimburstMate-Telgram-Bot/src/graph/graph.py:33: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'typing.Dict[str, typing.Any]'.
#   graph.add_node("extract_receipt", ExtractReceipt())
# /Users/sergio.fernandez/Documents - KV7M912HQ6/AI-Initiative/AI-Accelerators/Enroute-ReimburstMate-Telgram-Bot/src/graph/graph.py:34: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'typing.Dict[str, typing.Any]'.
#   graph.add_node("upsert_expense", UpsertExpense())
# /Users/sergio.fernandez/Documents - KV7M912HQ6/AI-Initiative/AI-Accelerators/Enroute-ReimburstMate-Telgram-Bot/src/graph/graph.py:35: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'typing.Dict[str, typing.Any]'.
#   graph.add_node("query_status", QueryStatus())
# /Users/sergio.fernandez/Documents - KV7M912HQ6/AI-Initiative/AI-Accelerators/Enroute-ReimburstMate-Telgram-Bot/src/graph/graph.py:36: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'typing.Dict[str, typing.Any]'.
#   graph.add_node("render_and_post", RenderAndPost())

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))
